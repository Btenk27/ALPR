# %% [markdown]
# # Training

# %%
from ultralytics import YOLO
from pathlib import Path
import torch
import os

# %% [markdown]
# # Cek GPU

# %%
print("="*50)

print("Cuda Available:",torch.cuda.is_available())
if torch.cuda.is_available():
    print("Cuda Device Name:", torch.cuda.get_device_name(0))
else:
    print("Cuda Device Name: None")

print("="*50)
# Out:
# ...
# Cuda Available: True
# Cuda Device Name: NVIDIA GeForce RTX 4050 Laptop GPU
# ...

# %% [markdown]
# # Path Dataset

# %%
from pathlib import Path
DATASET = "../datasets/anpr-model-1.v1i.yolov11/data.yaml"

assert Path(DATASET).exists(), "Dataset tidak ditemukan"

print(DATASET)
# Out:
# ../datasets/anpr-model-1.v1i.yolov11/data.yaml

# %% [markdown]
# # MODEL

# %%
model = YOLO("yolo11n.pt")
load_model = "yolo11n.pt"

EPOCHS = 100
IMAGE_SIZE = 640
BATCH = 16

PROJECT = "../outputs"

RUN_NAME = "plat_detector"

results = model.train(
    data=DATASET,
    epochs=EPOCHS,
    imgsz=IMAGE_SIZE,
    batch=BATCH,
    project=PROJECT,
    name=RUN_NAME,
    workers=4,
    device=0,
    pretrained=True,
    optimizer="auto",
    patience=30,
    save=True,
    plots=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.80 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.79 🚀 Python-3.12.13 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 5800MiB)
# ...

# %% [markdown]
# # Validasi

# %%
metrics = model.val()
# Out:
# Ultralytics 8.4.79 🚀 Python-3.12.13 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 5800MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 6559.6±1624.6 MB/s, size: 128.1 KB)
# val: Scanning /home/betenk/Documents/Porto/datasets/anpr-model-1.v1i.yolov11/valid/labels.cache... 194 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 194/194 135.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 10.3it/s 1.3s0.1s
#                    all        194        206      0.753      0.815      0.798      0.522
#                  plate        193        196      0.891       0.99      0.987      0.694
#                 toyota         10         10      0.614      0.639       0.61       0.35
# Speed: 0.7ms preprocess, 3.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# ...

# %% [markdown]
# # Menampilkan Folder Hasil

# %%
from pathlib import Path

result_path = Path(PROJECT) / RUN_NAME

print(result_path)
# Out:
# ../outputs/plat_detector

# %% [markdown]
# # Model Terbaik

# %%
best_model = Path(PROJECT) / RUN_NAME / "weights" / "best.pt"

print(best_model)
print(best_model.exists())
# Out:
# ../outputs/plat_detector/weights/best.pt
# False

# %% [markdown]
# # Informasi Training

# %%
print("="*50)
print("Training selesai")
print("Model terbaik :", best_model)
print("="*50)
# Out:
# ...
# Training selesai
# Model terbaik : ../outputs/plat_detector/weights/best.pt
# ...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
