# %% [markdown]
# # ALPR
#
# ## Environment Setup

# %%
import os
import sys
import platform
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch


from ultralytics import YOLO

# %% [markdown]
# # Python Information

# %%
print("Python Version:",
sys.version)
print("Platform:",
platform.platform())
print("Current path:",
os.getcwd())
# Out:
# Python Version: 3.12.13 (main, Jun  2 2026, 22:27:15) [Clang 22.1.3 ]
# Platform: Linux-7.0.11-arch1-1-x86_64-with-glibc2.43
# Current path: /home/betenk/Documents/Porto/notebooks

# %% [markdown]
# # Library Version

# %%
import ultralytics
import cv2
import numpy as np
import pandas as pd

print("Ultralytics:",
ultralytics.__version__)
print("OpenCV:",
cv2.__version__)
print("Numpy:",
np.__version__)
print("Pandas:",
pd.__version__)
# Out:
# Ultralytics: 8.4.79
# OpenCV: 4.13.0
# Numpy: 2.5.0
# Pandas: 3.0.3

# %% [markdown]
# # PyTorch Information

# %%
import torch

print("Torch:",
torch.__version__)
print("Torch CUDA available:",
torch.cuda.is_available())

if torch.cuda.is_available():
    print("Torch CUDA device name:",
    torch.cuda.get_device_name(0))

# %% [markdown]
# # Project Structure

# %%
for root, dirs, files in os.walk("/home/betenk/Documents/Porto/"):
    print(root)
# Out:
# /home/betenk/Documents/Porto/
# /home/betenk/Documents/Porto/.git
# /home/betenk/Documents/Porto/.git/hooks
# /home/betenk/Documents/Porto/.git/info
# /home/betenk/Documents/Porto/.git/objects
# /home/betenk/Documents/Porto/.git/objects/info
# /home/betenk/Documents/Porto/.git/objects/pack
# /home/betenk/Documents/Porto/.git/refs
# /home/betenk/Documents/Porto/.git/refs/heads
# /home/betenk/Documents/Porto/.git/refs/tags
# /home/betenk/Documents/Porto/notebooks
# /home/betenk/Documents/Porto/outputs
# /home/betenk/Documents/Porto/outputs/images
# /home/betenk/Documents/Porto/models
# /home/betenk/Documents/Porto/.venv
# /home/betenk/Documents/Porto/.venv/bin
# /home/betenk/Documents/Porto/.venv/share
# /home/betenk/Documents/Porto/.venv/share/man
# /home/betenk/Documents/Porto/.venv/share/man/man1
# /home/betenk/Documents/Porto/.venv/share/icons
# /home/betenk/Documents/Porto/.venv/share/icons/hicolor
# /home/betenk/Documents/Porto/.venv/share/icons/hicolor/scalable
# ...

# %% [markdown]
# # Dataset Checking

# %%
dataset_path = os.path.join("/home/betenk/Documents/Porto/datasets/anpr-model-1.v1i.yolov11")

print(os.path.exists(dataset_path))
print(os.path.isdir(dataset_path))
# Out:
# True
# True

# %% [markdown]
# # Environment Ready

# %%
print("=" * 40)
print("Environment setup completed successfully.")
print("=" * 40)
# Out:
# ...
# Environment setup completed successfully.
# ...
